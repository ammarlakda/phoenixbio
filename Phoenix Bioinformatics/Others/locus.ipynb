# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Using provided code to read from csv file

# %%
with open("gene_aliases_20210930.csv", 'r') as temp_f:
    # get No of columns in each line
    col_count = [ len(l.split(",")) for l in temp_f.readlines() ]

### Generate column names  (names will be 0, 1, 2, ..., maximum columns - 1)
column_names = [i for i in range(0, max(col_count))]

### Read csv
df = pd.read_csv("gene_aliases_20210930.csv", header=None, delimiter=",", names=column_names)

# %%
df.head(50)
# Out:
#              0          1       2    3  \
# 0   locus_name        NaN  symbol  NaN
# 1     18S RRNA   18S RRNA     NaN  NaN
# 2     25S RRNA   25S RRNA     NaN  NaN
# 3    5.8S RRNA  5.8S RRNA     NaN  NaN
# 4          AAN        AAN     NaN  NaN
# 5         AAR1       AAR1     NaN  NaN
# 6         AAR2       AAR2     NaN  NaN
# 7         ACL1       ACL1     NaN  NaN
# 8         ACL2       ACL2     NaN  NaN
# 9         ACL3       ACL3     NaN  NaN
# 10        ACL4       ACL4     NaN  NaN
# 11        ADD1       ADD1     NaN  NaN
# 12        ADD2       ADD2     NaN  NaN
# 13        ADD3       ADD3     NaN  NaN
# 14        ADE1       ADE1     NaN  NaN
# 15        AGE1       AGE1     NaN  NaN
# 16        AGE2       AGE2     NaN  NaN
# 17        AGI1       AGI1     NaN  NaN
# 18        AHR1       AHR1     NaN  NaN
# 19         AK2        AK2     NaN  NaN
# 20        ALB2       ALB2     NaN  NaN
# 21        ALB2    M4-6-18     NaN  NaN
# 22        ALF3       ALF3     NaN  NaN
# ...

# %%
print(pd.isnull(df).sum())
# Out:
# 0        0
# 1     1046
# 2     9141
# 3    27981
# 4    28851
# 5    28963
# 6    28963
# 7    28963
# 8    28963
# dtype: int64

# %% [markdown]
# Filter out rows with empty cells:

# %%
nan_rows = df.loc[df.isna().any(axis=1)]
print(nan_rows)
# Out:
#                                                 0          1       2    3  \
# 0                                      locus_name        NaN  symbol  NaN
# 1                                        18S RRNA   18S RRNA     NaN  NaN
# 2                                        25S RRNA   25S RRNA     NaN  NaN
# 3                                       5.8S RRNA  5.8S RRNA     NaN  NaN
# 4                                             AAN        AAN     NaN  NaN
# ...                                           ...        ...     ...  ...
# 28958                          pub_termannotation        NaN     NaN  NaN
# 28959       pub_termannotation_save\npub_termtype        NaN     NaN  NaN
# 28960                           pub_updatehistory        NaN     NaN  NaN
# 28961                                     pub_url        NaN     NaN  NaN
# 28962  pub_urllinking\npub_urlreference\npub_user        NaN     NaN  NaN
#
#                      4   5   6   7   8
# 0                  NaN NaN NaN NaN NaN
# ...

# %% [markdown]
# Delete rows with empty cells:

# %%
df_new = df.drop(nan_rows)

# %%
print(df_new.head(50))
# Out:
#             0        1    2    3  \
# 9        ACL3     ACL3  NaN  NaN
# 10       ACL4     ACL4  NaN  NaN
# 11       ADD1     ADD1  NaN  NaN
# 12       ADD2     ADD2  NaN  NaN
# 13       ADD3     ADD3  NaN  NaN
# 14       ADE1     ADE1  NaN  NaN
# 15       AGE1     AGE1  NaN  NaN
# 16       AGE2     AGE2  NaN  NaN
# 17       AGI1     AGI1  NaN  NaN
# 18       AHR1     AHR1  NaN  NaN
# 19        AK2      AK2  NaN  NaN
# 20       ALB2     ALB2  NaN  NaN
# 21       ALB2  M4-6-18  NaN  NaN
# 22       ALF3     ALF3  NaN  NaN
# 23        ALI      ALI  NaN  NaN
# 24    ALR-104  ALR-104  NaN  NaN
# 25    ALR-128  ALR-128  NaN  NaN
# 26       ALS2     ALS2  NaN  NaN
# 27       ALS4     ALS4  NaN  NaN
# 28       ALS5     ALS5  NaN  NaN
# 29       ALS7     ALS7  NaN  NaN
# 30      AMOS2    AMOS2  NaN  NaN
# 31        AND      AND  NaN  NaN
# 32       ANL1     ANL1  NaN  NaN
# 33       ARA1     Ara1  NaN  NaN
# 34       ARA2     ARA2  NaN  NaN
# 35      ARC10    ARC10  NaN  NaN
# ...

# %% [markdown]
# Delete rows at the end with random strings:

# %%
# number of rows to drop is difference between these numbers (end of random strings - beginning of random strings)
n = (28982-28903) 
df_final = df_new.iloc[:-n]

# %%
print(df_final.head(50))
# Out:
#             0        1    2    3  \
# 9        ACL3     ACL3  NaN  NaN
# 10       ACL4     ACL4  NaN  NaN
# 11       ADD1     ADD1  NaN  NaN
# 12       ADD2     ADD2  NaN  NaN
# 13       ADD3     ADD3  NaN  NaN
# 14       ADE1     ADE1  NaN  NaN
# 15       AGE1     AGE1  NaN  NaN
# 16       AGE2     AGE2  NaN  NaN
# 17       AGI1     AGI1  NaN  NaN
# 18       AHR1     AHR1  NaN  NaN
# 19        AK2      AK2  NaN  NaN
# 20       ALB2     ALB2  NaN  NaN
# 21       ALB2  M4-6-18  NaN  NaN
# 22       ALF3     ALF3  NaN  NaN
# 23        ALI      ALI  NaN  NaN
# 24    ALR-104  ALR-104  NaN  NaN
# 25    ALR-128  ALR-128  NaN  NaN
# 26       ALS2     ALS2  NaN  NaN
# 27       ALS4     ALS4  NaN  NaN
# 28       ALS5     ALS5  NaN  NaN
# 29       ALS7     ALS7  NaN  NaN
# 30      AMOS2    AMOS2  NaN  NaN
# 31        AND      AND  NaN  NaN
# 32       ANL1     ANL1  NaN  NaN
# 33       ARA1     Ara1  NaN  NaN
# 34       ARA2     ARA2  NaN  NaN
# 35      ARC10    ARC10  NaN  NaN
# ...

# %% [markdown]
# Printing last 50 entries of final dataframe to check if any are random strings at end of dataframe

# %%
print(df_final.tail(50))
# Out:
#              0       1                                             2  \
# 28834     SSI1    SSI1  SUPPRESSOR OF SALICYLIC ACID INSENSITIVITY 1
# 28835     SSI4    SSI4                                           NaN
# 28836      STA     STA                                           NaN
# 28837     STP1    STP1                               STUNTED PLANT 1
# 28838  SU(RGN)     NaN                                       SU(RGN)
# 28839      SUL     SUL                                     SULFURATA
# 28840     SUN7    SUN7                                           NaN
# 28841     SUS3  EMB158                          EMBRYO DEFECTIVE 158
# 28842     SUS3    SUS3                          ABNORMAL SUSPENSOR 3
# 28843     SUZ1    SUZ1                                           NaN
# 28844     SUZ2    SUZ2                                           NaN
# 28845     SUZ3    SUZ3                                           NaN
# 28846      SVN     SVN                   SPONTANEOUS VESSEL NECROSIS
# ...
